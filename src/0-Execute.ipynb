# %%
# %load_ext autoreload
# %autoreload 2


# %matplotlib inline

# %%
# %cd C:\MAD4AG
# Out:
# C:\MAD4AG

# %%
min_night_visit=3
min_score= 10
# %store min_night_visit
# %store min_score



# %run ".\src\3.1-Home-location-estimation.ipynb"
# Out:
# Stored 'min_night_visit' (int)
# Stored 'min_score' (int)
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\MAD4AG
# The number of stops:  28075949
# The number of stops in weekday and non-holiday:  13060259
#   0%|          | 0/72 [00:00<?, ?it/s]
# Data contains 364666 devices in weekdays-non holidays.
# The home location of 281017 devices was detected  (77.06 of all devices).
# The work/school location of 83649 devices could not be detected.
# 1892 devices most likely have two home locations.

# %%
# %store -d parameter

# %%
# %run ".\src\deneme.ipynb"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# no stored variable or alias parameter
# 20
# C:\MAD4AG

# %%
parameter =50
# %store parameter
# Out:
# Stored 'parameter' (int)

# %%
# %run ".\src\deneme.ipynb"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 50
# C:\MAD4AG

# %%
# %store -d parameter

# %%
# %run ".\src\deneme.ipynb"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# no stored variable or alias parameter
# 20
# C:\MAD4AG
